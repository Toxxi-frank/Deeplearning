# %% [markdown]
# <a href="https://colab.research.google.com/github/Toxxi-frank/Deeplearning/blob/main/Fraud_dec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks
# Out:
# /content/gdrive/MyDrive/Colab Notebooks

# %%
# !unzip fraud_data.zip
# Out:
# Archive:  fraud_data.zip
#   inflating: creditcard.csv

# %%
import pandas as pd
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/creditcard.csv')

# %%
df.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0   0.0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62      0
# 1   0.0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69      0
# 2   1.0 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66      0
# 3   1.0 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50      0
# 4   2.0 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
df.count()
#diem dong du lieu
# Out:
# Time      284807
# V1        284807
# V2        284807
# V3        284807
# V4        284807
# V5        284807
# V6        284807
# V7        284807
# V8        284807
# V9        284807
# V10       284807
# V11       284807
# V12       284807
# V13       284807
# V14       284807
# V15       284807
# V16       284807
# V17       284807
# V18       284807
# V19       284807
# V20       284807
# V21       284807
# V22       284807
# V23       284807
# V24       284807
# V25       284807
# V26       284807
# V27       284807
# V28       284807
# Amount    284807
# Class     284807
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#drop Time 
df_no_time = df.drop(columns=['Time'])
df_no_time.head()
# Out:
#          V1        V2        V3        V4  ...       V27       V28  Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  149.62      0
# 1  1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724    2.69      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ... -0.055353 -0.059752  378.66      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.062723  0.061458  123.50      0
# 4 -1.158233  0.877737  1.548718  0.403034  ...  0.219422  0.215153   69.99      0
#
# [5 rows x 30 columns]

# %%
from sklearn.preprocessing import StandardScaler
df_no_time['Amount'] = StandardScaler().fit_transform(df_no_time['Amount'].values.reshape(-1,1))
df_no_time.head()
# Out:
#          V1        V2        V3        V4  ...       V27       V28    Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.133558 -0.021053  0.244964      0
# 1  1.191857  0.266151  0.166480  0.448154  ... -0.008983  0.014724 -0.342475      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ... -0.055353 -0.059752  1.160686      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.062723  0.061458  0.140534      0
# 4 -1.158233  0.877737  1.548718  0.403034  ...  0.219422  0.215153 -0.073403      0
#
# [5 rows x 30 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(df_no_time, test_size=0.2, random_state=42)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (227845, 30) (56962, 30)

# %%
X_train = X_train[X_train["Class"]==0]
X_train = X_train.drop(columns=['Class'])

y_test = X_test['Class']
X_test = X_test.drop(columns=['Class'])

X_train = X_train.values
X_test = X_test.values

# %%
print(X_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (227451, 29)
# (56962, 29)
# (56962,)

# %%
from keras.layers import Input, Dense
from keras.models import load_model, Model
from keras.callbacks import ModelCheckpoint

# %%
input_dim = X_train.shape[1]
hidden_size = 128

# %%
# Build model
#Input
input_layer = Input(shape=(input_dim,))

#Encoder
encoder = Dense(hidden_size, activation='relu')(input_layer)
encoder = Dense(hidden_size//2, activation='relu')(encoder)
encoder = Dense(hidden_size//4, activation='relu')(encoder)

#Decoder
decoder = Dense(hidden_size//4, activation='relu')(encoder)
decoder = Dense(hidden_size//2, activation='relu')(decoder)
decoder = Dense(hidden_size, activation='relu')(decoder)

#Output
output_layer = Dense(input_dim, activation='relu')(decoder)

auto_encoder_model = Model(inputs= input_layer, outputs=output_layer)
auto_encoder_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 29)]              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3840
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_6 (Dense)              (None, 29)                3741
# =================================================================
# Total params: 29,405
# Trainable params: 29,405
# Non-trainable params: 0
# _________________________________________________________________

# %%
auto_encoder_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
n_epoch = 50
n_batch_size = 32

save_best = ModelCheckpoint(filepath='best.h5', verbose=1, monitor='val_loss', save_best_only=True)

history = auto_encoder_model.fit(X_train, X_train, batch_size=n_batch_size, epochs=n_epoch, verbose=1,
                       shuffle=True, callbacks=[save_best], validation_data=(X_test, X_test))
# Out:
# Epoch 1/50
# 7108/7108 [==============================] - 46s 4ms/step - loss: 0.6725 - accuracy: 0.7493 - val_loss: 0.6483 - val_accuracy: 0.8632
#
# Epoch 00001: val_loss improved from inf to 0.64827, saving model to best.h5
# Epoch 2/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.6101 - accuracy: 0.8761 - val_loss: 0.6564 - val_accuracy: 0.8672
#
# Epoch 00002: val_loss did not improve from 0.64827
# Epoch 3/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.6092 - accuracy: 0.8712 - val_loss: 0.6232 - val_accuracy: 0.9297
#
# Epoch 00003: val_loss improved from 0.64827 to 0.62316, saving model to best.h5
# Epoch 4/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5954 - accuracy: 0.9100 - val_loss: 0.6222 - val_accuracy: 0.9421
#
# Epoch 00004: val_loss improved from 0.62316 to 0.62217, saving model to best.h5
# Epoch 5/50
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.5993 - accuracy: 0.9054 - val_loss: 0.6322 - val_accuracy: 0.9257
#
# Epoch 00005: val_loss did not improve from 0.62217
# Epoch 6/50
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.5997 - accuracy: 0.9133 - val_loss: 0.6280 - val_accuracy: 0.9336
#
# Epoch 00006: val_loss did not improve from 0.62217
# Epoch 7/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5950 - accuracy: 0.9203 - val_loss: 0.6287 - val_accuracy: 0.9257
#
# Epoch 00007: val_loss did not improve from 0.62217
# Epoch 8/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5938 - accuracy: 0.9241 - val_loss: 0.6279 - val_accuracy: 0.9365
#
# Epoch 00008: val_loss did not improve from 0.62217
# Epoch 9/50
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.5960 - accuracy: 0.9313 - val_loss: 0.6286 - val_accuracy: 0.9453
#
# Epoch 00009: val_loss did not improve from 0.62217
# Epoch 10/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5923 - accuracy: 0.9345 - val_loss: 0.6297 - val_accuracy: 0.9222
#
# Epoch 00010: val_loss did not improve from 0.62217
# Epoch 11/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5893 - accuracy: 0.9363 - val_loss: 0.6397 - val_accuracy: 0.9353
#
# Epoch 00011: val_loss did not improve from 0.62217
# Epoch 12/50
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.6080 - accuracy: 0.9198 - val_loss: 0.6565 - val_accuracy: 0.9089
#
# Epoch 00012: val_loss did not improve from 0.62217
# Epoch 13/50
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.6286 - accuracy: 0.8905 - val_loss: 0.6602 - val_accuracy: 0.8753
#
# Epoch 00013: val_loss did not improve from 0.62217
# Epoch 14/50
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.6215 - accuracy: 0.8979 - val_loss: 0.6774 - val_accuracy: 0.8456
#
# Epoch 00014: val_loss did not improve from 0.62217
# Epoch 15/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.6260 - accuracy: 0.8894 - val_loss: 0.6280 - val_accuracy: 0.9359
#
# Epoch 00015: val_loss did not improve from 0.62217
# Epoch 16/50
# 7108/7108 [==============================] - 27s 4ms/step - loss: 0.5885 - accuracy: 0.9407 - val_loss: 0.6447 - val_accuracy: 0.8599
#
# Epoch 00016: val_loss did not improve from 0.62217
# Epoch 17/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5996 - accuracy: 0.9364 - val_loss: 0.6273 - val_accuracy: 0.9515
#
# Epoch 00017: val_loss did not improve from 0.62217
# Epoch 18/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5895 - accuracy: 0.9454 - val_loss: 0.6280 - val_accuracy: 0.9447
#
# Epoch 00018: val_loss did not improve from 0.62217
# Epoch 19/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5893 - accuracy: 0.9398 - val_loss: 0.6289 - val_accuracy: 0.9236
#
# Epoch 00019: val_loss did not improve from 0.62217
# Epoch 20/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5927 - accuracy: 0.9398 - val_loss: 0.6263 - val_accuracy: 0.9578
#
# Epoch 00020: val_loss did not improve from 0.62217
# Epoch 21/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5864 - accuracy: 0.9424 - val_loss: 0.6269 - val_accuracy: 0.9543
#
# Epoch 00021: val_loss did not improve from 0.62217
# Epoch 22/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5976 - accuracy: 0.9431 - val_loss: 0.6267 - val_accuracy: 0.9568
#
# Epoch 00022: val_loss did not improve from 0.62217
# Epoch 23/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5937 - accuracy: 0.9413 - val_loss: 0.6268 - val_accuracy: 0.9405
#
# Epoch 00023: val_loss did not improve from 0.62217
# Epoch 24/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5890 - accuracy: 0.9463 - val_loss: 0.6265 - val_accuracy: 0.9621
#
# Epoch 00024: val_loss did not improve from 0.62217
# Epoch 25/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.6047 - accuracy: 0.9431 - val_loss: 0.6272 - val_accuracy: 0.9482
#
# Epoch 00025: val_loss did not improve from 0.62217
# Epoch 26/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5916 - accuracy: 0.9456 - val_loss: 0.6282 - val_accuracy: 0.9448
#
# Epoch 00026: val_loss did not improve from 0.62217
# Epoch 27/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5886 - accuracy: 0.9446 - val_loss: 0.6270 - val_accuracy: 0.9563
#
# Epoch 00027: val_loss did not improve from 0.62217
# Epoch 28/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.6073 - accuracy: 0.9372 - val_loss: 0.6277 - val_accuracy: 0.9474
#
# Epoch 00028: val_loss did not improve from 0.62217
# Epoch 29/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5921 - accuracy: 0.9495 - val_loss: 0.6524 - val_accuracy: 0.8172
#
# Epoch 00029: val_loss did not improve from 0.62217
# Epoch 30/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.6008 - accuracy: 0.9398 - val_loss: 0.6263 - val_accuracy: 0.9674
#
# Epoch 00030: val_loss did not improve from 0.62217
# Epoch 31/50
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.5866 - accuracy: 0.9511 - val_loss: 0.6267 - val_accuracy: 0.9574
#
# Epoch 00031: val_loss did not improve from 0.62217
# Epoch 32/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5869 - accuracy: 0.9511 - val_loss: 0.6305 - val_accuracy: 0.9013
#
# Epoch 00032: val_loss did not improve from 0.62217
# Epoch 33/50
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.5933 - accuracy: 0.9453 - val_loss: 0.6267 - val_accuracy: 0.9554
#
# Epoch 00033: val_loss did not improve from 0.62217
# Epoch 34/50
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.5929 - accuracy: 0.9531 - val_loss: 0.6667 - val_accuracy: 0.7884
#
# Epoch 00034: val_loss did not improve from 0.62217
# Epoch 35/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5897 - accuracy: 0.9376 - val_loss: 0.6296 - val_accuracy: 0.9372
#
# Epoch 00035: val_loss did not improve from 0.62217
# Epoch 36/50
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.6003 - accuracy: 0.9471 - val_loss: 0.6278 - val_accuracy: 0.9593
#
# Epoch 00036: val_loss did not improve from 0.62217
# Epoch 37/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.6032 - accuracy: 0.9499 - val_loss: 0.6261 - val_accuracy: 0.9688
#
# Epoch 00037: val_loss did not improve from 0.62217
# Epoch 38/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5938 - accuracy: 0.9520 - val_loss: 0.6345 - val_accuracy: 0.8931
#
# Epoch 00038: val_loss did not improve from 0.62217
# Epoch 39/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5948 - accuracy: 0.9497 - val_loss: 0.6271 - val_accuracy: 0.9510
#
# Epoch 00039: val_loss did not improve from 0.62217
# Epoch 40/50
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.6081 - accuracy: 0.9206 - val_loss: 0.6560 - val_accuracy: 0.8391
#
# Epoch 00040: val_loss did not improve from 0.62217
# Epoch 41/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.6132 - accuracy: 0.8468 - val_loss: 0.6268 - val_accuracy: 0.9479
#
# Epoch 00041: val_loss did not improve from 0.62217
# Epoch 42/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5908 - accuracy: 0.9513 - val_loss: 0.6264 - val_accuracy: 0.9625
#
# Epoch 00042: val_loss did not improve from 0.62217
# Epoch 43/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5997 - accuracy: 0.9519 - val_loss: 0.6265 - val_accuracy: 0.9576
#
# Epoch 00043: val_loss did not improve from 0.62217
# Epoch 44/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5870 - accuracy: 0.9529 - val_loss: 0.6262 - val_accuracy: 0.9607
#
# Epoch 00044: val_loss did not improve from 0.62217
# Epoch 45/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5927 - accuracy: 0.9538 - val_loss: 0.6265 - val_accuracy: 0.9614
#
# Epoch 00045: val_loss did not improve from 0.62217
# Epoch 46/50
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.6058 - accuracy: 0.9524 - val_loss: 0.6265 - val_accuracy: 0.9604
#
# Epoch 00046: val_loss did not improve from 0.62217
# Epoch 47/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5968 - accuracy: 0.9511 - val_loss: 0.6264 - val_accuracy: 0.9568
#
# Epoch 00047: val_loss did not improve from 0.62217
# Epoch 48/50
# 7108/7108 [==============================] - 30s 4ms/step - loss: 0.5933 - accuracy: 0.9548 - val_loss: 0.6265 - val_accuracy: 0.9615
#
# Epoch 00048: val_loss did not improve from 0.62217
# Epoch 49/50
# 7108/7108 [==============================] - 28s 4ms/step - loss: 0.5892 - accuracy: 0.9528 - val_loss: 0.6207 - val_accuracy: 0.9508
#
# Epoch 00049: val_loss improved from 0.62217 to 0.62071, saving model to best.h5
# Epoch 50/50
# 7108/7108 [==============================] - 29s 4ms/step - loss: 0.5898 - accuracy: 0.9497 - val_loss: 0.6194 - val_accuracy: 0.9663
#
# Epoch 00050: val_loss improved from 0.62071 to 0.61940, saving model to best.h5

# %%
saved_model = tf.keras.models.load_model("best.h5")

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend()

plt.xlabel("epoch")
plt.ylabel("loss")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f1b0953bf521> in <module>()
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 plt.plot(history.history['loss'])
#       4 plt.plot(history.history['val_loss'])
#       5 plt.legend()
#
# NameError: name 'history' is not defined

# %%
import numpy as np

# Dự đoán
predicts = auto_encoder_model.predict(X_test)
mse = np.mean(np.power(X_test - predicts,2), axis=1)
err_df = pd.DataFrame({'error': mse, 'truth': y_test})

# %%
# In ra histogram của error khi tái tạo các điểm Normal trong tập test
normal_error_df = err_df[(err_df['truth']==0) & (err_df['error'] < 10)]

_ = plt.hist(normal_error_df.error.values, bins= 50)

# %%
# In ra histogram của error khi tái tạo các điểm Fraud trong tập test
fraud_error_df = err_df[(err_df['truth']==1)]
_ = plt.hist(fraud_error_df.error.values, bins= 100)

# %%
# Vẽ ra confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns

threshold = 1

y_pred = [1 if e > threshold else 0 for e in err_df.error.values]
conf_matrix = confusion_matrix(err_df.truth, y_pred)

# Vẽ
sns.heatmap(conf_matrix, xticklabels=["Normal", "Fraud"], yticklabels=['Normal','Fraud'], annot=True, fmt="d")
plt.title("Confusion Matrix")
plt.xlabel("Predited Values")
plt.ylabel("Truth")
plt.show
